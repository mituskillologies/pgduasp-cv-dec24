# %%
import cv2
import matplotlib.pyplot as plt
import numpy

# %%
# read the image
image = cv2.imread('images/lenna.png')

# %%
# Define starting and ending points of the line
start_point = (100, 50)  # (x1, y1)
end_point = (300, 200)   # (x2, y2)

# Draw a green line with thickness of 2 pixels
cv2.line(image, start_point, end_point, (0, 255, 0), 2);

cv2.imshow('Image with Line', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# read the image
image = cv2.imread('images/lenna.png')

# Draw a green line with thickness of 2 pixels
cv2.line(image, (0,0), (512, 512), (0, 0, 255), 2);
cv2.line(image, (512,0), (0, 512), (0, 0, 255), 2);

cv2.imshow('Image with Line', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ###### Draw using equation

# %%
import numpy as np

# %%
x = np.arange(1,100,0.25)

# %%
x
# Out:
# array([ 1.  ,  1.25,  1.5 ,  1.75,  2.  ,  2.25,  2.5 ,  2.75,  3.  ,
#         3.25,  3.5 ,  3.75,  4.  ,  4.25,  4.5 ,  4.75,  5.  ,  5.25,
#         5.5 ,  5.75,  6.  ,  6.25,  6.5 ,  6.75,  7.  ,  7.25,  7.5 ,
#         7.75,  8.  ,  8.25,  8.5 ,  8.75,  9.  ,  9.25,  9.5 ,  9.75,
#        10.  , 10.25, 10.5 , 10.75, 11.  , 11.25, 11.5 , 11.75, 12.  ,
#        12.25, 12.5 , 12.75, 13.  , 13.25, 13.5 , 13.75, 14.  , 14.25,
#        14.5 , 14.75, 15.  , 15.25, 15.5 , 15.75, 16.  , 16.25, 16.5 ,
#        16.75, 17.  , 17.25, 17.5 , 17.75, 18.  , 18.25, 18.5 , 18.75,
#        19.  , 19.25, 19.5 , 19.75, 20.  , 20.25, 20.5 , 20.75, 21.  ,
#        21.25, 21.5 , 21.75, 22.  , 22.25, 22.5 , 22.75, 23.  , 23.25,
#        23.5 , 23.75, 24.  , 24.25, 24.5 , 24.75, 25.  , 25.25, 25.5 ,
#        25.75, 26.  , 26.25, 26.5 , 26.75, 27.  , 27.25, 27.5 , 27.75,
#        28.  , 28.25, 28.5 , 28.75, 29.  , 29.25, 29.5 , 29.75, 30.  ,
#        30.25, 30.5 , 30.75, 31.  , 31.25, 31.5 , 31.75, 32.  , 32.25,
#        32.5 , 32.75, 33.  , 33.25, 33.5 , 33.75, 34.  , 34.25, 34.5 ,
#        34.75, 35.  , 35.25, 35.5 , 35.75, 36.  , 36.25, 36.5 , 36.75,
#        37.  , 37.25, 37.5 , 37.75, 38.  , 38.25, 38.5 , 38.75, 39.  ,
#        39.25, 39.5 , 39.75, 40.  , 40.25, 40.5 , 40.75, 41.  , 41.25,
#        41.5 , 41.75, 42.  , 42.25, 42.5 , 42.75, 43.  , 43.25, 43.5 ,
#        43.75, 44.  , 44.25, 44.5 , 44.75, 45.  , 45.25, 45.5 , 45.75,
#        46.  , 46.25, 46.5 , 46.75, 47.  , 47.25, 47.5 , 47.75, 48.  ,
#        48.25, 48.5 , 48.75, 49.  , 49.25, 49.5 , 49.75, 50.  , 50.25,
#        50.5 , 50.75, 51.  , 51.25, 51.5 , 51.75, 52.  , 52.25, 52.5 ,
#        52.75, 53.  , 53.25, 53.5 , 53.75, 54.  , 54.25, 54.5 , 54.75,
#        55.  , 55.25, 55.5 , 55.75, 56.  , 56.25, 56.5 , 56.75, 57.  ,
#        57.25, 57.5 , 57.75, 58.  , 58.25, 58.5 , 58.75, 59.  , 59.25,
#        59.5 , 59.75, 60.  , 60.25, 60.5 , 60.75, 61.  , 61.25, 61.5 ,
#        61.75, 62.  , 62.25, 62.5 , 62.75, 63.  , 63.25, 63.5 , 63.75,
#        64.  , 64.25, 64.5 , 64.75, 65.  , 65.25, 65.5 , 65.75, 66.  ,
#        66.25, 66.5 , 66.75, 67.  , 67.25, 67.5 , 67.75, 68.  , 68.25,
#        68.5 , 68.75, 69.  , 69.25, 69.5 , 69.75, 70.  , 70.25, 70.5 ,
#        70.75, 71.  , 71.25, 71.5 , 71.75, 72.  , 72.25, 72.5 , 72.75,
#        73.  , 73.25, 73.5 , 73.75, 74.  , 74.25, 74.5 , 74.75, 75.  ,
#        75.25, 75.5 , 75.75, 76.  , 76.25, 76.5 , 76.75, 77.  , 77.25,
#        77.5 , 77.75, 78.  , 78.25, 78.5 , 78.75, 79.  , 79.25, 79.5 ,
#        79.75, 80.  , 80.25, 80.5 , 80.75, 81.  , 81.25, 81.5 , 81.75,
#        82.  , 82.25, 82.5 , 82.75, 83.  , 83.25, 83.5 , 83.75, 84.  ,
#        84.25, 84.5 , 84.75, 85.  , 85.25, 85.5 , 85.75, 86.  , 86.25,
#        86.5 , 86.75, 87.  , 87.25, 87.5 , 87.75, 88.  , 88.25, 88.5 ,
#        88.75, 89.  , 89.25, 89.5 , 89.75, 90.  , 90.25, 90.5 , 90.75,
#        91.  , 91.25, 91.5 , 91.75, 92.  , 92.25, 92.5 , 92.75, 93.  ,
#        93.25, 93.5 , 93.75, 94.  , 94.25, 94.5 , 94.75, 95.  , 95.25,
#        95.5 , 95.75, 96.  , 96.25, 96.5 , 96.75, 97.  , 97.25, 97.5 ,
#        97.75, 98.  , 98.25, 98.5 , 98.75, 99.  , 99.25, 99.5 , 99.75])

# %%
y = 37.8 * x + 34.0288

# %%
y
# Out:
# array([  71.8288,   81.2788,   90.7288,  100.1788,  109.6288,  119.0788,
#         128.5288,  137.9788,  147.4288,  156.8788,  166.3288,  175.7788,
#         185.2288,  194.6788,  204.1288,  213.5788,  223.0288,  232.4788,
#         241.9288,  251.3788,  260.8288,  270.2788,  279.7288,  289.1788,
#         298.6288,  308.0788,  317.5288,  326.9788,  336.4288,  345.8788,
#         355.3288,  364.7788,  374.2288,  383.6788,  393.1288,  402.5788,
#         412.0288,  421.4788,  430.9288,  440.3788,  449.8288,  459.2788,
#         468.7288,  478.1788,  487.6288,  497.0788,  506.5288,  515.9788,
#         525.4288,  534.8788,  544.3288,  553.7788,  563.2288,  572.6788,
#         582.1288,  591.5788,  601.0288,  610.4788,  619.9288,  629.3788,
#         638.8288,  648.2788,  657.7288,  667.1788,  676.6288,  686.0788,
#         695.5288,  704.9788,  714.4288,  723.8788,  733.3288,  742.7788,
#         752.2288,  761.6788,  771.1288,  780.5788,  790.0288,  799.4788,
#         808.9288,  818.3788,  827.8288,  837.2788,  846.7288,  856.1788,
#         865.6288,  875.0788,  884.5288,  893.9788,  903.4288,  912.8788,
#         922.3288,  931.7788,  941.2288,  950.6788,  960.1288,  969.5788,
#         979.0288,  988.4788,  997.9288, 1007.3788, 1016.8288, 1026.2788,
#        1035.7288, 1045.1788, 1054.6288, 1064.0788, 1073.5288, 1082.9788,
#        1092.4288, 1101.8788, 1111.3288, 1120.7788, 1130.2288, 1139.6788,
#        1149.1288, 1158.5788, 1168.0288, 1177.4788, 1186.9288, 1196.3788,
#        1205.8288, 1215.2788, 1224.7288, 1234.1788, 1243.6288, 1253.0788,
#        1262.5288, 1271.9788, 1281.4288, 1290.8788, 1300.3288, 1309.7788,
#        1319.2288, 1328.6788, 1338.1288, 1347.5788, 1357.0288, 1366.4788,
#        1375.9288, 1385.3788, 1394.8288, 1404.2788, 1413.7288, 1423.1788,
#        1432.6288, 1442.0788, 1451.5288, 1460.9788, 1470.4288, 1479.8788,
#        1489.3288, 1498.7788, 1508.2288, 1517.6788, 1527.1288, 1536.5788,
#        1546.0288, 1555.4788, 1564.9288, 1574.3788, 1583.8288, 1593.2788,
#        1602.7288, 1612.1788, 1621.6288, 1631.0788, 1640.5288, 1649.9788,
#        1659.4288, 1668.8788, 1678.3288, 1687.7788, 1697.2288, 1706.6788,
#        1716.1288, 1725.5788, 1735.0288, 1744.4788, 1753.9288, 1763.3788,
#        1772.8288, 1782.2788, 1791.7288, 1801.1788, 1810.6288, 1820.0788,
#        1829.5288, 1838.9788, 1848.4288, 1857.8788, 1867.3288, 1876.7788,
#        1886.2288, 1895.6788, 1905.1288, 1914.5788, 1924.0288, 1933.4788,
#        1942.9288, 1952.3788, 1961.8288, 1971.2788, 1980.7288, 1990.1788,
#        1999.6288, 2009.0788, 2018.5288, 2027.9788, 2037.4288, 2046.8788,
#        2056.3288, 2065.7788, 2075.2288, 2084.6788, 2094.1288, 2103.5788,
#        2113.0288, 2122.4788, 2131.9288, 2141.3788, 2150.8288, 2160.2788,
#        2169.7288, 2179.1788, 2188.6288, 2198.0788, 2207.5288, 2216.9788,
#        2226.4288, 2235.8788, 2245.3288, 2254.7788, 2264.2288, 2273.6788,
#        2283.1288, 2292.5788, 2302.0288, 2311.4788, 2320.9288, 2330.3788,
#        2339.8288, 2349.2788, 2358.7288, 2368.1788, 2377.6288, 2387.0788,
#        2396.5288, 2405.9788, 2415.4288, 2424.8788, 2434.3288, 2443.7788,
#        2453.2288, 2462.6788, 2472.1288, 2481.5788, 2491.0288, 2500.4788,
#        2509.9288, 2519.3788, 2528.8288, 2538.2788, 2547.7288, 2557.1788,
#        2566.6288, 2576.0788, 2585.5288, 2594.9788, 2604.4288, 2613.8788,
#        2623.3288, 2632.7788, 2642.2288, 2651.6788, 2661.1288, 2670.5788,
#        2680.0288, 2689.4788, 2698.9288, 2708.3788, 2717.8288, 2727.2788,
#        2736.7288, 2746.1788, 2755.6288, 2765.0788, 2774.5288, 2783.9788,
#        2793.4288, 2802.8788, 2812.3288, 2821.7788, 2831.2288, 2840.6788,
#        2850.1288, 2859.5788, 2869.0288, 2878.4788, 2887.9288, 2897.3788,
#        2906.8288, 2916.2788, 2925.7288, 2935.1788, 2944.6288, 2954.0788,
#        2963.5288, 2972.9788, 2982.4288, 2991.8788, 3001.3288, 3010.7788,
#        3020.2288, 3029.6788, 3039.1288, 3048.5788, 3058.0288, 3067.4788,
#        3076.9288, 3086.3788, 3095.8288, 3105.2788, 3114.7288, 3124.1788,
#        3133.6288, 3143.0788, 3152.5288, 3161.9788, 3171.4288, 3180.8788,
#        3190.3288, 3199.7788, 3209.2288, 3218.6788, 3228.1288, 3237.5788,
#        3247.0288, 3256.4788, 3265.9288, 3275.3788, 3284.8288, 3294.2788,
#        3303.7288, 3313.1788, 3322.6288, 3332.0788, 3341.5288, 3350.9788,
#        3360.4288, 3369.8788, 3379.3288, 3388.7788, 3398.2288, 3407.6788,
#        3417.1288, 3426.5788, 3436.0288, 3445.4788, 3454.9288, 3464.3788,
#        3473.8288, 3483.2788, 3492.7288, 3502.1788, 3511.6288, 3521.0788,
#        3530.5288, 3539.9788, 3549.4288, 3558.8788, 3568.3288, 3577.7788,
#        3587.2288, 3596.6788, 3606.1288, 3615.5788, 3625.0288, 3634.4788,
#        3643.9288, 3653.3788, 3662.8288, 3672.2788, 3681.7288, 3691.1788,
#        3700.6288, 3710.0788, 3719.5288, 3728.9788, 3738.4288, 3747.8788,
#        3757.3288, 3766.7788, 3776.2288, 3785.6788, 3795.1288, 3804.5788])

# %%
plt.scatter(x, y, marker = '.')
plt.plot(x, y, color = 'orange')

# %% [markdown]
# ###### Drawing a 3D line

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# Define start and end points of the line in 3D space
start_point = (10, 22, 33)
end_point = (44, 52, 67)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the line
ax.plot([start_point[0], end_point[0]],
        [start_point[1], end_point[1]],
        [start_point[2], end_point[2]], 'r-')

ax.plot([10, 40],[55, 35],[35, 30],'g')

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Line')

# Show the plot
plt.show()

# %% [markdown]
# ###### Line using turtle

# %%
import turtle

# Create a turtle object
t = turtle.Turtle()

# Set the line width (optional)
t.pensize(1)

# Move the turtle to the starting position
t.penup()
t.goto(0, -50)  # Replace with your desired starting coordinates (x, y)
t.pendown()

# Move the turtle to the ending position (drawing the line)
t.goto(300, 0)  # Replace with your desired ending coordinates (x, y)

# Keep the window open until closed manually
turtle.done()

# %% [markdown]
# ##### Rectangle Drawing

# %%
# Load your image
image = cv2.imread("images/lenna.png")

# Define top-left corner and dimensions
x, y, w, h = 100, 50, 200, 150

# Draw a blue rectangle with thickness of 2 pixels
cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 10)

# Show the image with the rectangle
cv2.imshow("Image with Rectangle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Load your image
image = cv2.imread("images/lenna.png")

cv2.rectangle(image, (0, 0), (255,255), (255, 255, 0), 10)
cv2.rectangle(image, (255, 0), (512,255), (127, 255, 0), 10)
cv2.rectangle(image, (0, 255), (255,512), (127, 255, 255), 10)
cv2.rectangle(image, (255, 255), (512,512), (0, 0, 255), 10)

# Show the image with the rectangle
cv2.imshow("Image with Rectangle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np

image = np.ones([200,300]) - 0.25
cv2.rectangle(image, (50, 50), (250, 150), (0, 140, 0), 10)
cv2.imshow('Sample Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Rectangle using matplotlib

# %%
# Define rectangle coordinates
x_min, y_min, x_max, y_max = 1, 2, 4, 7

# Create the rectangle patch
rectangle = plt.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min,
                         color='red', alpha=0.1)

# Add the rectangle to a plot and customize labels/title
plt.plot([x_min, x_max], [y_min, y_min], 'b-', label='X-axis')
plt.plot([x_min, x_min], [y_min, y_max], 'g-', label='Y-axis')
plt.gca().add_patch(rectangle)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Rectangle Plot")
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ##### Rectangle using turtle

# %%
import turtle
t = turtle.Turtle()
# Set color and pen size
t.color("green")
t.pensize(5)
t.speed(0)
# Move the Turtle and draw the rectangle
t.penup()
t.goto(-50, 25)
t.pendown()
t.forward(100)
t.left(90)
t.forward(50)
t.left(90)
t.forward(100)
t.left(90)
t.forward(50)
t.hideturtle()

# Start the Turtle graphics window
turtle.done()

# %% [markdown]
# ##### Drawing the ellipse

# %%
# Load an image
image = cv2.imread("images/lenna.png")

# Define center coordinates, radii, and angle
center = (150, 100)  # (x, y)
axes = (100, 50)  # (major_radius, minor_radius)
angle = 45  # Angle of rotation in degrees

# Draw a green ellipse with thickness of 3 pixels
cv2.ellipse(image, center, axes, angle, 0, 360, (0, 255, 0), 3)
cv2.ellipse(image, (200,400), axes, 0, 0, 360, (0, 255, 0), 3)

# Display the image with the ellipse
cv2.imshow("Image with Ellipse", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Load an image
image = cv2.imread("images/lenna.png")

# Define center coordinates, radii, and angle
center = (255, 255)  # (x, y)
axes = (150, 255)  # (major_radius, minor_radius)
angle = 0  # Angle of rotation in degrees

# Draw a green ellipse with thickness of 3 pixels
cv2.ellipse(image, center, axes, angle, 0, 360, (0, 255, 255), 50)

# Display the image with the ellipse
cv2.imshow("Image with Ellipse", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = cv2.imread("images/lenna.png")

# Define center coordinates, radii, and angle
center = (255, 255)  # (x, y)
axes = (150, 255)  # (major_radius, minor_radius)
angle = 0  # Angle of rotation in degrees

# Draw a green ellipse with thickness of 3 pixels
cv2.ellipse(image, center, axes, angle, 180, 360, (255, 0, 0), 15)
cv2.ellipse(image, center, axes, angle, 0, 180, (0, 0, 255), 5)

# Display the image with the ellipse
cv2.imshow("Image with Ellipse", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Ellipse using matplotlib

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# Define center coordinates, radii, and angle
center = (0, 0)
width = 8
height = 5
angle = 45

# Create the ellipse object
ellipse = Ellipse(xy=center, width=width, height=height, angle=angle, color='blue')

# Add the ellipse to the plot
fig, ax = plt.subplots()
ax.add_patch(ellipse)
ax.set_aspect('equal')  # Maintain equal aspect ratio for correct shape

# Set limits slightly wider than the ellipse
ax.set_xlim(-width - width/5, width + width/5)
ax.set_ylim(-height - height/5, height + height/5)

# Add labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Ellipse Plot')

# Show the plot
plt.show()

# %% [markdown]
# ##### Drawing circle

# %%
# Load an image
image = cv2.imread("images/lenna.png")

# Define center coordinates, radii, and angle
center = (255, 255)  # (x, y)
axes = (150, 255)  # (major_radius, minor_radius)
angle = 0  # Angle of rotation in degrees

# Draw a green ellipse with thickness of 3 pixels
cv2.ellipse(image, center, (150,150), angle, 0, 360, (0, 255, 0), 5)

# Display the image with the ellipse
cv2.imshow("Image with Ellipse", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Load an image
image = cv2.imread("images/lenna.png")

# Define center coordinates and radius
center = (100, 100)  # (x, y)
radius = 50

# Draw a red circle with thickness of 4 pixels
cv2.circle(image, center, radius, (127, 127, 0), 4)

# Display the image with the circle
cv2.imshow("Image with Circle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Load an image
image = cv2.imread("images/lenna.png")

# Define center coordinates and radius
center = (255, 255)  # (x, y)

# Draw a red circle with thickness of 4 pixels
for i in range(1,401,5):
    cv2.circle(image, center, i, (0, i//2, i), 2)

# Display the image with the circle
cv2.imshow("Image with Circle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Circle using matplotlib

# %%
# Define center coordinates and radius
center = (0, 0)
radius = 3

# Create the circle object
circle = plt.Circle(xy=center, radius=radius, color='orange')

# Add the circle to the plot
fig, ax = plt.subplots()
ax.add_patch(circle)
ax.set_aspect('equal')  # Maintain equal aspect ratio for correct shape

# Set limits slightly wider than the circle
ax.set_xlim(-radius - radius/5, radius + radius/5)
ax.set_ylim(-radius - radius/5, radius + radius/5)

# Add labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Circle Plot')

# Show the plot
plt.show()

# %% [markdown]
# ##### Canvas

# %%
from tkinter import *

# %%
# Create the object of UI window
top = Tk()

# Keep it running infinitely
top.mainloop()

# %%
# Create the object of UI window
top = Tk()
top.title('My Application')
top.geometry('400x300')
# Keep it running infinitely
top.mainloop()

# %%
# Create the object of UI window
top = Tk()
top.title('My Application')
top.geometry('400x300')

l = Label(top,text="Enter your name")
e = Entry(top)
b = Button(top, text='Click Here')

l.pack()
e.pack()
b.pack()

# Keep it running infinitely
top.mainloop()

# %%
# Create the object of UI window
top = Tk()
top.title('My Application')
top.geometry('400x300')

Label(top,text="Enter your name").pack()
Entry(top).pack()
Button(top, text='Click Here').pack()

# Keep it running infinitely
top.mainloop()

# %%
# Create the object of UI window
top = Tk()
top.title('My Application')
top.geometry('400x300')

def show():
    name = e.get()
    print('Welcome',name)

Label(top,text="Enter your name").pack()
e = Entry(top)
e.pack()
Button(top, text='Click Here', command=show).pack()

# Keep it running infinitely
top.mainloop()
# Out:
# Welcome Tushar
# Welcome Tushar
# Welcome Tushar
# Welcome Ajay

# %%
# Create the object of UI window
top = Tk()
top.title('My Application')
top.geometry('400x300')

def show():
    num = int(e.get())
    print('Square is:', num ** 2)

Label(top,text="Enter a number:").pack()
e = Entry(top)
e.pack()
Button(top, text='Find Square', command=show).pack()

# Keep it running infinitely
top.mainloop()
# Out:
# Square is: 144

# %%
# Create the object of UI window
top = Tk()
top.title('My Application')
top.geometry('400x300')

def show():
    num = int(e.get())
    result.config(text='Square is:'+str(num**2))

Label(top,text="Enter a number:").pack()
e = Entry(top)
e.pack()
Button(top, text='Find Square', command=show).pack()
result = Label(text='Square is:')
result.pack()

# Keep it running infinitely
top.mainloop()

# %%
# Create the object of UI window
top = Tk()
top.title('My Application')
top.geometry('400x300')

def show():
    num = int(e.get())
    result.config(text='Square is: '+str(num**2))

Label(top,text="Enter a number:").place(x=50, y=50)
e = Entry(top)
e.place(x=200, y=50)
Button(top, text='Find Square', command=show).place(x=50, y=120)
result = Label(text='Square is:')
result.place(x=50, y=190)

# Keep it running infinitely
top.mainloop()

# %% [markdown]
# ###### Simple Calculator

# %%
# Create the object of UI window
top = Tk()
top.title('My Application')
top.geometry('500x300')

def add():
    num = int(e1.get()) + int(e2.get())
    result.config(text='Addition: '+str(num))

def sub():
    num = int(e1.get()) - int(e2.get())
    result.config(text='Subtraction: '+str(num))

def mul():
    num = int(e1.get()) * int(e2.get())
    result.config(text='Multiplication: '+str(num))

def div():
    num = int(e1.get()) / int(e2.get())
    result.config(text='Division: '+str(num))

Label(top,text="Num1:").place(x=50, y=50); e1 = Entry(top)
e1.place(x=100, y=50)

Label(top,text="Num2:").place(x=200, y=50); e2 = Entry(top)
e2.place(x=250, y=50)

Button(top, text='Add', command=add).place(x=50, y=120)
Button(top, text='Sub', command=sub).place(x=120, y=120)
Button(top, text='Mul', command=mul).place(x=190, y=120)
Button(top, text='Div', command=div).place(x=260, y=120)
result = Label(text='Result:')
result.place(x=50, y=190)

# Keep it running infinitely
top.mainloop()

# %%
# Create the main window
root = Tk()
root.title("Drawing Canvas")
root.geometry('1000x800')

# Create the canvas widget
canvas = Canvas(root, width=1000, height=800, bg="white")
canvas.pack()

# Define drawing functions
def draw_line(event):
    x1, y1 = event.x, event.y
    canvas.create_line(x1, y1, x1+2, y1+2, width=10)
    
def draw_circle(event):
    x1, y1 = event.x, event.y
    canvas.create_oval(x1 - 15, y1 - 15, x1 + 15, y1 + 15, fill="yellow")

# Bind mouse events to drawing functions
canvas.bind("<Button-3>", draw_circle)
canvas.bind("<B1-Motion>", draw_line)

# Start the main loop
root.mainloop()

# %% [markdown]
# ##### Mouse Operations

# %%
import cv2

# Load an image
img = cv2.imread("images/lenna.png")

# Define the callback function
def draw_circle(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN: 
        cv2.circle(img, (x, y), 10, (0, 255, 0), -1)  # Draw a green circle

# Bind the callback function
cv2.namedWindow("image")
cv2.setMouseCallback("image", draw_circle)

# Show the image and wait for events
while True:
    cv2.imshow("image", img)
    if cv2.waitKey(1) == ord("q"):
        break

cv2.destroyAllWindows()

# %% [markdown]
# ##### Image Annotations

# %%
import cv2

# Define text and rectangle properties
text = "Lenna"
font_face = cv2.FONT_HERSHEY_COMPLEX
font_scale = 1.0
color = (122, 105, 0)  # Green
thickness = 5

# Calculate text width and height
text_size, baseline = cv2.getTextSize(text, font_face, font_scale, thickness)

# Define text and rectangle positions
text_origin = (100, 100)
box_origin = (text_origin[0] - 10, text_origin[1] - baseline - 20)
box_width, box_height = text_size[0] + 20, text_size[1] + 20

image = cv2.imread("images/lenna.png")

# Draw the rectangle and text
cv2.rectangle(image, box_origin, (box_origin[0] + box_width, 
                                  box_origin[1] + box_height), color, thickness)
cv2.putText(image, text, text_origin, font_face, font_scale, color, thickness)

# Display the annotated image
cv2.imshow("Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Annotations using matplotlib

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [2, 5, 1]

plt.plot(x, y, marker = 'o')
plt.text(2, 5, "Data Point", fontsize=14, color="red")  # Annotate a specific point
plt.text(1.1, 2, "Starting Point", fontsize=14, color="green")
plt.text(3, 1.1, "End Point", fontsize=14, color="yellow")
plt.title("Example Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
plt.plot(x, y, marker = 'o', color = 'blue')
plt.annotate("Peak value", (2, 5), xytext=(1.5, 5.5), 
             arrowprops=dict(edgecolor='red', facecolor='green'))
plt.annotate("Start value", (1.05, 2), xytext=(1.25, 1.5), 
             arrowprops=dict(edgecolor='magenta', facecolor='yellow'))
plt.annotate("End value", (3, 1), xytext=(2.5, 1.1), 
             arrowprops=dict(edgecolor='black', facecolor='pink'))
plt.show()
